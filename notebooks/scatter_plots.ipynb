# %% [markdown]
# # Scatter plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from itertools import combinations
import plotly.io as pio
import seaborn as sns
pio.renderers.default = 'browser'

# %%
df = pd.read_csv('..\datasets\spotify_limpo.csv')

CLUSTER_FEATURES = [
    'danceability',
    'energy',
    'loudness',
    'speechiness',
    'acousticness',
    'valence',
    'tempo'
]
# Out:
# <>:1: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# <>:1: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# C:\Users\Allan\AppData\Local\Temp\ipykernel_13052\3719764999.py:1: SyntaxWarning:
#
# invalid escape sequence '\d'

# %%
# Estatísticas descritivas
print(df['tempo'].describe(percentiles=[0.01, 0.05, 0.95, 0.99]))

# Boxplot
sns.boxplot(y=df['tempo'])
plt.title('Boxplot de Tempo')
plt.show()

# Histograma
sns.histplot(df['tempo'], bins=30)
plt.title('Histograma de Tempo')
plt.show()
# Out:
# count    81344.000000
# mean       122.198986
# std         29.934974
# min         30.200000
# 1%          64.936290
# 5%          77.003150
# 50%        122.030000
# 95%        174.990000
# 99%        192.632420
# max        224.000000
# Name: tempo, dtype: float64

# %%
feature_pairs = list(combinations(CLUSTER_FEATURES, 2))[:6]  # Você pode aumentar esse número

# Gerar vários plots
figs = []
for x_feature, y_feature in feature_pairs:
    fig = px.scatter(
        df,
        x=x_feature,
        y=y_feature,
        color="cluster" if "cluster" in df.columns else None,
        hover_data=["track_name", "artists", "track_genre"],
        title=f"{x_feature} vs {y_feature}",
        height=500,
        width=600
    )
    fig.show()
